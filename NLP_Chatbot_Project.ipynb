# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# Chatbot Training Data
training_data = [
    ("hello", "Hello! How can I help you today?"),
    ("hi", "Hey! What can I do for you?"),
    ("how are you", "I'm doing great! Thanks for asking. How about you?"),
    ("what is your name", "I'm your AI assistant. You can call me Nova!"),
    ("who created you", "I was created as part of an NLP project."),
    ("bye", "Goodbye! Have a great day!"),
    ("thanks", "You're welcome! Happy to help."),
    ("thank you", "No problem! Let me know if you need anything else."),
    ("what can you do", "I can chat with you and answer simple questions for now."),
    ("i am sad", "I'm sorry you're feeling that way. Want to talk about it?"),
    ("i am happy", "That's awesome! I'm happy for you."),
    ("tell me a joke", "Why don't programmers like nature? Too many bugs!"),
    ("who are you", "I'm a friendly chatbot trained using machine learning."),
    ("how old are you", "I don't age! I'm always fresh and running."),
]

# %%
import json

intents = {
    "intents": [
        {
            "tag": "greeting",
            "patterns": ["Hi", "Hello", "Hey", "Is anyone there?", "Good morning", "Good evening"],
            "responses": ["Hello! How can I help you today?", "Hi there! What can I do for you?"]
        },
        {
            "tag": "goodbye",
            "patterns": ["Bye", "See you later", "Goodbye", "I have to go"],
            "responses": ["Goodbye! Have a great day!", "See you later!", "Take care!"]
        },
        {
            "tag": "thanks",
            "patterns": ["Thanks", "Thank you", "That was helpful"],
            "responses": ["You're welcome!", "Happy to help!", "Anytime!"]
        },
        {
            "tag": "name",
            "patterns": ["What is your name?", "Who are you?", "Tell me about yourself"],
            "responses": ["I'm your friendly assistant chatbot!", "I am an AI created to help you!"]
        },
        {
            "tag": "help",
            "patterns": ["I need help", "Can you help me?", "I have a doubt"],
            "responses": ["Sure! Tell me what you need help with.", "I'm here to assist you!"]
        }
    ]
}

with open('intents.json', 'w') as json_file:
    json.dump(intents, json_file, indent=4)

print("✅ Dataset created: intents.json")
# Out:
# ✅ Dataset created: intents.json

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import numpy as np
import pickle
import random

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Load dataset
with open('intents.json') as file:
    data = json.load(file)

words = []
classes = []
documents = []
ignore_letters = ['?', '!', '.', ',']

for intent in data['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_letters]
words = sorted(set(words))
classes = sorted(set(classes))

# Save words and classes
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

print("✅ Preprocessing complete")
print(f"Total words: {len(words)}")
print(f"Total classes: {len(classes)}")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-2740448446.py in <cell line: 0>()
#      20 for intent in data['intents']:
#      21     for pattern in intent['patterns']:
# ---> 22         word_list = nltk.word_tokenize(pattern)
#      23         words.extend(word_list)
#      24         documents.append((word_list, intent['tag']))
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
# ...

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# !pip install tensorflow

# %%
# !pip install tensorflow

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import json
import pickle
import nltk
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Load dataset
with open('intents.json') as file:
    data = json.load(file)

print("✅ Required data and tools loaded")
# Out:
# ✅ Required data and tools loaded
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import numpy as np
import pickle
import random

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Load dataset
with open('intents.json') as file:
    data = json.load(file)

words = []
classes = []
documents = []
ignore_letters = ['?', '!', '.', ',']

for intent in data['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_letters]
words = sorted(set(words))
classes = sorted(set(classes))

# Save words and classes
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

print("✅ Preprocessing complete")
print(f"Total words: {len(words)}")
print(f"Total classes: {len(classes)}")
# Out:
# ✅ Preprocessing complete
# Total words: 37
# Total classes: 5

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
import numpy as np
import random
import pickle
import nltk

# Load data
words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
training = []

for intent in data['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        word_list = [lemmatizer.lemmatize(word.lower()) for word in word_list]
        bag = [1 if word in word_list else 0 for word in words]
        output_row = [0] * len(classes)
        output_row[classes.index(intent['tag'])] = 1
        training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)
train_x = list(training[:, 0])
train_y = list(training[:, 1])

# Build Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile Model
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Train Model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("✅ Model trained and saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-239721515.py in <cell line: 0>()
#      22
#      23 random.shuffle(training)
# ---> 24 training = np.array(training)
#      25 train_x = list(training[:, 0])
#      26 train_y = list(training[:, 1])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (19, 2) + inhomogeneous part.

# %%
random.shuffle(training)
training = np.array(training)
train_x = list(training[:, 0])
train_y = list(training[:, 1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2233580499.py in <cell line: 0>()
#       1 random.shuffle(training)
# ----> 2 training = np.array(training)
#       3 train_x = list(training[:, 0])
#       4 train_y = list(training[:, 1])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (19, 2) + inhomogeneous part.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import json
import numpy as np
import pickle
import random

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Load dataset
with open('intents.json') as file:
    data = json.load(file)

words = []
classes = []
documents = []
ignore_letters = ['?', '!', '.', ',']

# Tokenization and preparing words, classes, documents
for intent in data['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# Lemmatization and lowercasing
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_letters]
words = sorted(set(words))
classes = sorted(set(classes))

# Save words and classes
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# Create training data
training = []
output_empty = [0] * len(classes)

for document in documents:
    bag = []
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in document[0]]

    # Create bag of words array
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append([bag, output_row])

# Shuffle and separate input/output
random.shuffle(training)
train_x = [item[0] for item in training]
train_y = [item[1] for item in training]

print("✅ Preprocessing and training data creation complete")
print(f"Total training samples: {len(training)}")
print(f"Input vector size: {len(train_x[0])}")
print(f"Output categories: {len(train_y[0])}")
# Out:
# ✅ Preprocessing and training data creation complete
# Total training samples: 19
# Input vector size: 37
# Output categories: 5

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
import numpy as np
import pickle

# Load training data
train_x = np.array(train_x)
train_y = np.array(train_y)

# Build model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Train model
model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)

# Save model
model.save('chatbot_model.h5')
print("✅ Model trained and saved as chatbot_model.h5")
# Out:
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.2775 - loss: 1.5677
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4951 - loss: 1.5254
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4063 - loss: 1.5654
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3463 - loss: 1.5468
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2253 - loss: 1.5733
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5361 - loss: 1.4877
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4274 - loss: 1.4694
# Epoch 8/200
# ...

# %%
import random
import json
import pickle
import numpy as np
import nltk
from tensorflow.keras.models import load_model
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# Load files and model
model = load_model('chatbot_model.h5')
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))

def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def bag_of_words(sentence):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

def predict_class(sentence):
    bow = bag_of_words(sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
    return return_list

def get_response(intents_list, intents_json):
    if len(intents_list) == 0:
        return "Sorry, I didn't understand that. Can you rephrase?"
    tag = intents_list[0]['intent']
    for i in intents_json['intents']:
        if i['tag'] == tag:
            return random.choice(i['responses'])

def chatbot_response(msg):
    ints = predict_class(msg)
    res = get_response(ints, intents)
    return res

print("✅ Chatbot is loaded and ready!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Chatbot is loaded and ready!

# %%
while True:
    message = input("You: ")
    if message.lower() == "quit":
        break
    response = chatbot_response(message)
    print("Bot:", response)
# Out:
# You: hi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Bot: Hi there! What can I do for you?
# You: i am dine
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Bot: I'm here to assist you!
# You: hey there
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Bot: Hello! How can I help you today?
# You: when should i eat
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Bot: I'm here to assist you!
# You: okay bye
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Bot: Take care!

# %%
intents_json = """
PASTE THE WHOLE JSON HERE INSIDE TRIPLE QUOTES
"""

with open("intents.json", "w") as file:
    file.write(intents_json)

print("✅ intents.json replaced successfully!")

# %%
{
  "intents": [
    {
      "tag": "greeting",
      "patterns": ["Hi", "Hello", "Hey", "Is anyone there?", "Good day"],
      "responses": ["Hello!", "Hi there, how can I assist you?", "Hey! What can I do for you?"]
    },
    {
      "tag": "goodbye",
      "patterns": ["Bye", "See you later", "Goodbye"],
      "responses": ["Goodbye!", "See you later!", "Have a great day!"]
    },
    {
      "tag": "thanks",
      "patterns": ["Thanks", "Thank you", "Thanks for helping me"],
      "responses": ["You're welcome!", "Glad to help!", "Anytime!"]
    },
    {
      "tag": "noanswer",
      "patterns": [""],
      "responses": ["Sorry, I don’t understand. Can you rephrase?"]
    },
    {
      "tag": "options",
      "patterns": ["What can you do?", "Help me", "Show options"],
      "responses": ["I can chat with you, motivate you, suggest movies, and even give workout tips!"]
    },
    {
      "tag": "creator",
      "patterns": ["Who created you?", "Who made you?", "Tell me about your creator"],
      "responses": ["I was created by Adhi, a passionate developer working on AI projects!"]
    },
    {
      "tag": "motivation",
      "patterns": ["Motivate me", "Tell me something inspiring", "I need motivation"],
      "responses": [
        "Wake up with determination. Go to bed with satisfaction.",
        "The only limit to our realization of tomorrow is our doubts of today.",
        "Success is not final, failure is not fatal: it is the courage to continue that counts."
      ]
    },
    {
      "tag": "workout",
      "patterns": ["Give me a workout", "Suggest a workout", "What’s today’s workout?"],
      "responses": [
        "Here’s a killer full-body routine: 20 push-ups, 20 squats, 10 pull-ups, plank 1 min. Repeat 3x.",
        "Try this today: 15 burpees, 20 lunges per leg, 30-second mountain climbers, 15 bench dips. 4 rounds!",
        "Chest day: 4x12 pushups, 4x10 bench press, 4x12 chest fly, 4x15 dumbbell squeeze press."
      ]
    },
    {
      "tag": "movies",
      "patterns": ["Suggest a movie", "Recommend a movie", "Give me a movie to watch"],
      "responses": [
        "Check out 'Interstellar' if you’re into sci-fi drama.",
        "'Shawshank Redemption' is a powerful story of hope.",
        "If you love thrillers, go for 'Shutter Island'."
      ]
    }
  ]
}

# %%
while True:
    message = input("You: ")
    if message.lower() == "quit":
        break
    response = chatbot_response(message)
    print("Bot:", response)
